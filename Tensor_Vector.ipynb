# %% [markdown]
# <a href="https://colab.research.google.com/github/Chandan0034/CodeCompiler/blob/main/Tensor_Vector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a=np.array([1,2,3,4,5])
plt.pie(a)
plt.show()

# %%
mat=np.array([[1,2,3],[4,5,6]])
mat.size
# Out:
# 6
